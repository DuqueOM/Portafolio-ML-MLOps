# %% [markdown]
# # Presentation — TelecomAI Customer Intelligence
# ## Objetivo
# Clasificar clientes para recomendar plan Ultra vs Smart.

# %% [markdown]
# ## Resultados
# - Métricas principales en `artifacts/metrics.json`
# - Matriz de confusión y curva ROC en `artifacts/`
