# %% [markdown]
# # Exploratory Data Analysis — TelecomAI
# Dataset: `users_behavior.csv`

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../users_behavior.csv')
df.head()

# %%
df.describe()

# %%
sns.pairplot(df[['calls','minutes','messages','mb_used','is_ultra']], hue='is_ultra');
plt.show()
